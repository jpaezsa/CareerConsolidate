# %%
from search_engine_mine import return_jobs_from_dice2
from search_engine_mine import stack_jobs
from search_engine_mine import get_monster_jobs
from search_engine_mine import get_careerbuilder_jobs

# %%
def all_search(position, location):
    jobs = []
    jobs += return_jobs_from_dice2(position, location)
    jobs += stack_jobs(position, location)
    jobs += get_monster_jobs(position, location)
    jobs += get_careerbuilder_jobs(position, location)
    return jobs

# %%
all_jobs = all_search('python developer', 'Chicago, IL')
# Out:
# send: 'GET / HTTP/1.1\r\nHost: www.dice.com\r\nUser-Agent: Mozilla/5.0(X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1\r\nConnection: close\r\nAccept-Encoding: gzip\r\n\r\n'
# reply:
#  'HTTP/1.1 200 OK\r\n'
# header: Server: Apache
# header: Vary: Accept-Encoding
# header: Content-Type: text/html; charset=ISO-8859-1
# header: Content-Encoding: gzip
# header: P3P: CP="ALL ADMi DEVi PSA CONi OUR DELi SAMi BUS NAV COM CNT ONL INT PHY DEM UNI"
# header: Date: Thu, 18 Apr 2013 04:17:44 GMT
# header: Keep-Alive: timeout=5, max=95
# header: Connection: close
# header: Set-Cookie: MERCURYDCSP=1QxjRvzLn1LwTg3JrlllNlyJjbYKnq9S2ShknxXH2xytXCnYFF9V!1788385068!1936078557; domain=.dice.com; path=/; HttpOnly
# header: Set-Cookie: REL_CODE=1102; domain=.dice.com; path=/
# header: Set-Cookie: VISIT50322=c0c7df1e5d8418ec9eccf92ac6c0e136; domain=.dice.com; expires=Saturday, 18-Apr-2015 04:17:44 GMT; path=/
# header: X-Powered-By: Servlet/2.5 JSP/2.1
# send:
# ...

# %%
for i in all_jobs:
    print i.text
# Out:
# Python Developer
# Python Developer with Datawarehouse exp for CA, IL
# Junior Python Developer
# Python Web Developer
# Python Developer
# Back-End Python Developer - Back-End, Python, RDBMS, MySQL
# Python Developer
# Python Django Developer
# Mongo DB Developer
# Mongo Developer
# Senior Solutions Developer - Production Team
# Software Developer
# Web developers! If you have Ruby on Rails/UI experience apply today!
# C++ Software Developer/Senior C++ Software Developer
# Software Developer
# Senior C#/.NET Developer
# Senior Software Development Engineer in Test - Mobile and CE devices
# Software Developer III/Software Architect
# Mobile App & Web Developer
# QA Engineer
# ETL/ SQL Developer with Unix Scripting
# Software Engineer
# Platform Developer
# SalesForce.com Developer - A great balance of work & rewards!
# C++ Developer
# IT Developer/Tester
# C++ DEVELOPERS
# C++/Unix-Linux Trading - Chi
# Web Integration Developer
# Front End Developer
# Automation Test Engineer
# ...

# %%
dir(all_jobs[0])
# Out:
# ['__cmp__',
#  '__doc__',
#  '__init__',
#  '__module__',
#  '__repr__',
#  'absolute_url',
#  'attrs',
#  'base_url',
#  'tag',
#  'text',
#  'url']

# %%
for i in all_jobs:
    print i.absolute_url
# Out:
# http://www.dice.com/job/result/10238894/52?src=19&q=python%20developer
# http://www.dice.com/job/result/10206536/113221?src=19&q=python%20developer
# http://www.dice.com/job/result/RTX173c96/wspos084163?src=19&q=python%20developer
# http://www.dice.com/job/result/cxmodoak/36624055?src=19&q=python%20developer
# http://www.dice.com/job/result/10114281/RQSOPY?src=19&q=python%20developer
# http://www.dice.com/job/result/cybercod/RF-PythonWebDeveloper4?src=19&q=python%20developer
# http://www.dice.com/job/result/10115700a/304369?src=19&q=python%20developer
# http://www.dice.com/job/result/swapps/Python_IL?src=19&q=python%20developer
# http://www.dice.com/job/result/10493077/0214?src=19&q=python%20developer
# http://www.dice.com/job/result/10212425/116577?src=19&q=python%20developer
# http://www.dice.com/job/result/10202401/2013-011?src=19&q=python%20developer
# http://www.dice.com/job/result/RTX151404/080924?src=19&q=python%20developer
# ...

# %%
for i in
